# %% [markdown]
# <a href="https://colab.research.google.com/github/logiha/northstar-database-analytics/blob/main/NorthStar_SQL_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("reticulate")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("googledrive")
library(googledrive)

drive_auth()
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Is it OK to cache OAuth access credentials in the folder ~/.cache/gargle
# between R sessions?
# 1: Yes
# 2: No
# Selection: 1
# Please point your browser to the following url:
#
# https://accounts.google.com/o/oauth2/v2/auth?client_id=603366585132-frjlouoa3s2ono25d2l9ukvhlsrlnr7k.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email&redirect_uri=https%3A%2F%2Fwww.tidyverse.org%2Fgoogle-callback%2F&response_type=code&state=eb4b673a2b84658d3eb7d0a1ed59517a&access_type=offline&prompt=consent
# Enter authorization code: eyJjb2RlIjoiNC8wQWVvV3VNOG1fbW1SMDVpSTJYUjJqZzlsR1dvS0pzTC1KNDZiQ2NHZDNOVG5VREo4aG0yaURVSWNja2lKTTI4Rnk1WjZDZyIsInN0YXRlIjoiZWI0YjY3M2EyYjg0NjU4ZDNlYjdkMGExZWQ1OTUxN2EifQ==

# %%
library(googledrive)

drive_deauth()

drive_auth(
  scopes = "https://www.googleapis.com/auth/drive"
)
# Out:
# The googledrive package is requesting access to your Google account.
# Enter '1' to start a new auth process or select a pre-authorized account.
# 1: Send me to the browser for a new auth process.
# 2: logiha.thayaparan28@gmail.com
# Selection: 1
# Please point your browser to the following url:
#
# https://accounts.google.com/o/oauth2/v2/auth?client_id=603366585132-frjlouoa3s2ono25d2l9ukvhlsrlnr7k.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email&redirect_uri=https%3A%2F%2Fwww.tidyverse.org%2Fgoogle-callback%2F&response_type=code&state=cd76d480a0cc1e5d4b299ff50afb6cf4&access_type=offline&prompt=consent
# Enter authorization code: eyJjb2RlIjoiNC8wQWVvV3VNOUhoYTlYTFdIRDhDWVFOUGRQVFp6MUFacGV4eENYSkNOZzFhWTlPRm5XUFpuNVE1T0dqbXBxUlpESFIzRkRpUSIsInN0YXRlIjoiY2Q3NmQ0ODBhMGNjMWU1ZDRiMjk5ZmY1MGFmYjZjZjQifQ==

# %%
deliveries_file <- drive_get("NorthStar_dataset/deliveries.csv")

drive_download(
  deliveries_file,
  path = "deliveries.csv",
  overwrite = TRUE
)

deliveries <- read.csv("deliveries.csv")

head(deliveries)
# Out:
# ✔ The input `path` resolved to exactly 1 file.
#
# File downloaded:
#
# • deliveries.csv <id: 1nQ_z6NFzhicxOHKsqEaOgFzCo7ODMuWX>
#
# Saved locally as:
#
# • deliveries.csv
#   delivery_id order_id driver_id vehicle_id hub_id dispatch_time
# 1 DL00001     O00938   D004      V056       H05    2024-06-18 10:57:00
# 2 DL00002     O00004   D138      V007       H02    2025-01-11 18:45:00
# 3 DL00003     O00639   D006      V049       H02    2025-06-02 20:39:00
# 4 DL00004     O00313   D116      V055       H02    2024-03-08 23:31:00
# 5 DL00005     O00844   D108      V034       H01    2025-09-21 11:43:00
# 6 DL00006     O00029   D037      V098       H03    2024-09-11 12:40:00
#   delivery_completed_at      delivery_status route_distance_km
# 1 2024-06-19 09:05:59.904311 Failed          17.26
# 2 2025-01-11 17:39:00.000000 OnTime          10.34
# 3 2025-06-02 21:45:32.366770 OnTime           7.92
# 4 2024-03-09 23:30:08.103702 Delayed         16.42
# 5 2025-09-21 15:45:34.131056 OnTime          14.52
# 6 2024-09-12 17:11:52.384869 Delayed         13.84
#   manual_route_override_count proof_of_completion_missing
# 1 1                           0
# 2 1                           0
# 3 0                           0
# 4 0                           0
# 5 1                           0
# 6 0                           0
#   customer_rating_post_delivery fuel_or_charge_cost
# 1 3.07                          12.05
# 2 5.00                          13.41
# 3 4.98                           8.51
# 4 4.18                          13.62
# 5 4.18                           9.22
# 6 1.57                           9.58

# %%
drive_find(n_max = 5)
# Out:
# ERROR while rich displaying an object: Error in (function (..., row.names = NULL, check.rows = FALSE, check.names = TRUE, : arguments imply differing number of rows: 1, 0
#
# Traceback:
# 1. sapply(x, f, simplify = simplify)
# 2. lapply(X = X, FUN = FUN, ...)
# 3. FUN(X[[i]], ...)
# 4. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 5. tryCatchList(expr, classes, parentenv, handlers)
# 6. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 7. doTryCatch(return(expr), name, parentenv, handler)
# 8. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 9. repr::mime2repr[[mime]](obj)
# 10. repr_text.data.frame(obj)
# 11. ellip_limit_arr(obj, rows, cols)
# 12. arr_parts_format(parts)
# 13. structure(lapply(parts, arr_part_format), omit = attr(parts,
#   .     "omit"))
# 14. lapply(parts, arr_part_format)
# 15. FUN(X[[i]], ...)
# 16. arr_part_unpack_tbl(part)
# 17. mapply(tbl_col_format, tbl, names(tbl), SIMPLIFY = FALSE, USE.NAMES = FALSE)
# 18. (function (col, prefix = "")
#   . {
#   .     if (is.data.frame(col)) {
#   .         res <- mapply(tbl_col_format, col, names(col), SIMPLIFY = FALSE,
#   .             USE.NAMES = FALSE)
#   .         res <- do.call(cbind.data.frame, res)
#   .         names(res) <- paste0(prefix, "$", names(res))
#   .         return(res)
#   .     }
#   .     else {
#   .         res <- data.frame(col)
#   .         names(res) <- prefix
#   .         return(res)
#   .     }
#   . })(dots[[1L]][[3L]], dots[[2L]][[3L]])
# 19. data.frame(col)
# 20. as.data.frame(x[[i]], optional = TRUE, stringsAsFactors = stringsAsFactors)
# 21. as.data.frame.list(x[[i]], optional = TRUE, stringsAsFactors = stringsAsFactors)
# 22. do.call(data.frame, c(x, alis))
# 23. (function (..., row.names = NULL, check.rows = FALSE, check.names = TRUE,
#   .     fix.empty.names = TRUE, stringsAsFactors = FALSE)
#   . {
#   .     data.row.names <- if (check.rows && is.null(row.names))
#   .         function(current, new, i) {
#   .             if (is.character(current))
#   .                 new <- as.character(new)
#   .             if (is.character(new))
#   .                 current <- as.character(current)
#   .             if (anyDuplicated(new))
#   .                 return(current)
#   .             if (is.null(current))
#   .                 return(new)
#   .             if (all(current == new) || all(current == ""))
#   .                 return(new)
#   .             stop(gettextf("mismatch of row names in arguments of 'data.frame', item %d",
#   .                 i), domain = NA)
#   .         }
#   .     else function(current, new, i) {
#   .         current %||% if (anyDuplicated(new)) {
#   .             warning(gettextf("some row.names duplicated: %s --> row.names NOT used",
#   .                 paste(which(duplicated(new)), collapse = ",")),
#   .                 domain = NA)
#   .             current
#   .         }
#   .         else new
#   .     }
#   .     object <- as.list(substitute(list(...)))[-1L]
#   .     mirn <- missing(row.names)
#   .     mrn <- is.null(row.names)
#   .     x <- list(...)
#   .     n <- length(x)
#   .     if (n < 1L) {
#   .         if (!mrn) {
#   .             if (is.object(row.names) || !is.integer(row.names))
#   .                 row.names <- as.character(row.names)
#   .             if (anyNA(row.names))
#   .                 stop("row names contain missing values")
#   .             if (anyDuplicated(row.names))
#   .                 stop(gettextf("duplicate row.names: %s", paste(unique(row.names[duplicated(row.names)]),
#   .                   collapse = ", ")), domain = NA)
#   .         }
#   .         else row.names <- integer()
#   .         return(structure(list(), names = character(), row.names = row.names,
#   .             class = "data.frame"))
#   .     }
#   .     vnames <- names(x)
#   .     if (length(vnames) != n)
#   .         vnames <- character(n)
#   .     no.vn <- !nzchar(vnames)
#   .     vlist <- vnames <- as.list(vnames)
#   .     nrows <- ncols <- integer(n)
#   .     for (i in seq_len(n)) {
#   .         xi <- if (is.character(x[[i]]) || is.list(x[[i]]))
#   .             as.data.frame(x[[i]], optional = TRUE, stringsAsFactors = stringsAsFactors)
#   .         else as.data.frame(x[[i]], optional = TRUE)
#   .         nrows[i] <- .row_names_info(xi)
#   .         ncols[i] <- length(xi)
#   .         namesi <- names(xi)
#   .         if (ncols[i] > 1L) {
#   .             if (length(namesi) == 0L)
#   .                 namesi <- seq_len(ncols[i])
#   .             vnames[[i]] <- if (no.vn[i])
#   .                 namesi
#   .             else paste(vnames[[i]], namesi, sep = ".")
#   .         }
#   .         else if (length(namesi)) {
#   .             vnames[[i]] <- namesi
#   .         }
#   .         else if (fix.empty.names && no.vn[[i]]) {
#   .             tmpname <- deparse(object[[i]], nlines = 1L)[1L]
#   .             if (startsWith(tmpname, "I(") && endsWith(tmpname,
#   .                 ")")) {
#   .                 ntmpn <- nchar(tmpname, "c")
#   .                 tmpname <- substr(tmpname, 3L, ntmpn - 1L)
#   .             }
#   .             vnames[[i]] <- tmpname
#   .         }
#   .         if (mirn && nrows[i] > 0L) {
#   .             rowsi <- attr(xi, "row.names")
#   .             if (any(nzchar(rowsi)))
#   .                 row.names <- data.row.names(row.names, rowsi,
#   .                   i)
#   .         }
#   .         nrows[i] <- abs(nrows[i])
#   .         vlist[[i]] <- xi
#   .     }
#   .     nr <- max(nrows)
#   .     for (i in seq_len(n)[nrows < nr]) {
#   .         xi <- vlist[[i]]
#   .         if (nrows[i] > 0L && (nr%%nrows[i] == 0L)) {
#   .             xi <- unclass(xi)
#   .             fixed <- TRUE
#   .             for (j in seq_along(xi)) {
#   .                 xi1 <- xi[[j]]
#   .                 if (is.vector(xi1) || is.factor(xi1))
#   .                   xi[[j]] <- rep(xi1, length.out = nr)
#   .                 else if (is.character(xi1) && inherits(xi1, "AsIs"))
#   .                   xi[[j]] <- structure(rep(xi1, length.out = nr),
#   .                     class = class(xi1))
#   .                 else if (inherits(xi1, "Date") || inherits(xi1,
#   .                   "POSIXct"))
#   .                   xi[[j]] <- rep(xi1, length.out = nr)
#   .                 else {
#   .                   fixed <- FALSE
#   .                   break
#   .                 }
#   .             }
#   .             if (fixed) {
#   .                 vlist[[i]] <- xi
#   .                 next
#   .             }
#   .         }
#   .         stop(gettextf("arguments imply differing number of rows: %s",
#   .             paste(unique(nrows), collapse = ", ")), domain = NA)
#   .     }
#   .     value <- unlist(vlist, recursive = FALSE, use.names = FALSE)
#   .     vnames <- as.character(unlist(vnames[ncols > 0L]))
#   .     if (fix.empty.names && any(noname <- !nzchar(vnames)))
#   .         vnames[noname] <- paste0("Var.", seq_along(vnames))[noname]
#   .     if (check.names) {
#   .         if (fix.empty.names)
#   .             vnames <- make.names(vnames, unique = TRUE)
#   .         else {
#   .             nz <- nzchar(vnames)
#   .             vnames[nz] <- make.names(vnames[nz], unique = TRUE)
#   .         }
#   .     }
#   .     names(value) <- vnames
#   .     if (!mrn) {
#   .         if (length(row.names) == 1L && nr != 1L) {
#   .             if (is.character(row.names))
#   .                 row.names <- match(row.names, vnames, 0L)
#   .             if (length(row.names) != 1L || row.names < 1L ||
#   .                 row.names > length(vnames))
#   .                 stop("'row.names' should specify one of the variables")
#   .             i <- row.names
#   .             row.names <- value[[i]]
#   .             value <- value[-i]
#   .         }
#   .         else if (!is.null(row.names) && length(row.names) !=
#   .             nr)
#   .             stop("row names supplied are of the wrong length")
#   .     }
#   .     else if (!is.null(row.names) && length(row.names) != nr) {
#   .         warning("row names were found from a short variable and have been discarded")
#   .         row.names <- NULL
#   .     }
#   .     class(value) <- "data.frame"
#   .     if (is.null(row.names))
#   .         attr(value, "row.names") <- .set_row_names(nr)
#   .     else {
#   .         if (is.object(row.names) || !is.integer(row.names))
#   .             row.names <- as.character(row.names)
#   .         if (anyNA(row.names))
#   .             stop("row names contain missing values")
#   .         if (anyDuplicated(row.names))
#   .             stop(gettextf("duplicate row.names: %s", paste(unique(row.names[duplicated(row.names)]),
#   .                 collapse = ", ")), domain = NA)
#   .         row.names(value) <- row.names
#   .     }
#   .     value
#   . })(list(kind = "drive#file", fileExtension = "ipynb", copyRequiresWriterPermission = FALSE,
#   .     md5Checksum = "819bcf78b6adcce3dfce36527528d4e9", writersCanShare = TRUE,
#   .     viewedByMe = TRUE, mimeType = "application/vnd.google.colaboratory",
#   .     parents = list("1PECBDf2-29jgmkXM3_wpiEfRRoTEgMje"), iconLink = "https://drive-thirdparty.googleusercontent.com/16/type/application/vnd.google.colaboratory",
#   .     shared = FALSE, lastModifyingUser = list(displayName = "Logiha Thayaparan",
#   .         kind = "drive#user", me = TRUE, permissionId = "12963107500983395456",
#   .         emailAddress = "logiha.thayaparan28@gmail.com", photoLink = "https://lh3.googleusercontent.com/a/ACg8ocJERnztX66xHnGkqf1LP4CPdrlXOOeTEBjjF-eRuw7F1sQGbQ=s64"),
#   .     owners = list(list(displayName = "Logiha Thayaparan", kind = "drive#user",
#   .         me = TRUE, permissionId = "12963107500983395456", emailAddress = "logiha.thayaparan28@gmail.com",
#   .         photoLink = "https://lh3.googleusercontent.com/a/ACg8ocJERnztX66xHnGkqf1LP4CPdrlXOOeTEBjjF-eRuw7F1sQGbQ=s64")),
#   .     headRevisionId = "0B988eXyT-r3ydnJWVTNreTZWc2xPWTlmL3pVb0w3ZzlWdHNzPQ",
#   .     webViewLink = "https://colab.research.google.com/drive/1rfDybs8Z9MhRdg_ON6Il0f3MIteeiFGE",
#   .     webContentLink = "https://drive.google.com/uc?id=1rfDybs8Z9MhRdg_ON6Il0f3MIteeiFGE&export=download",
#   .     size = "84408", viewersCanCopyContent = TRUE, permissions = list(
#   .         list(id = "12963107500983395456", displayName = "Logiha Thayaparan",
#   .             type = "user", kind = "drive#permission", photoLink = "https://lh3.googleusercontent.com/a/ACg8ocJERnztX66xHnGkqf1LP4CPdrlXOOeTEBjjF-eRuw7F1sQGbQ=s64",
#   .             emailAddress = "logiha.thayaparan28@gmail.com", role = "owner",
#   .             deleted = FALSE, pendingOwner = FALSE)), hasThumbnail = FALSE,
#   .     spaces = list("drive"), id = "1rfDybs8Z9MhRdg_ON6Il0f3MIteeiFGE",
#   .     name = "NorthStar_SQL_R.ipynb", description = "Colab notebook",
#   .     starred = FALSE, trashed = FALSE, explicitlyTrashed = FALSE,
#   .     createdTime = "2026-05-23T12:10:14.760Z", modifiedTime = "2026-05-23T12:36:12.212Z",
#   .     modifiedByMeTime = "2026-05-23T12:36:12.212Z", viewedByMeTime = "2026-05-23T12:36:12.212Z",
#   .     quotaBytesUsed = "84408", version = "24", originalFilename = "NorthStar_SQL_R.ipynb",
#   .     ownedByMe = TRUE, fullFileExtension = "ipynb", isAppAuthorized = FALSE,
#   .     capabilities = list(canChangeViewersCanCopyContent = TRUE,
#   .         canEdit = TRUE, canCopy = TRUE, canComment = TRUE, canAddChildren = FALSE,
#   .         canDelete = TRUE, canDownload = TRUE, canListChildren = FALSE,
#   .         canRemoveChildren = FALSE, canRename = TRUE, canTrash = TRUE,
#   .         canReadRevisions = TRUE, canChangeCopyRequiresWriterPermission = TRUE,
#   .         canMoveItemIntoTeamDrive = TRUE, canUntrash = TRUE, canModifyContent = TRUE,
#   .         canMoveItemOutOfDrive = TRUE, canAddMyDriveParent = FALSE,
#   .         canRemoveMyDriveParent = TRUE, canMoveItemWithinDrive = TRUE,
#   .         canShare = TRUE, canMoveChildrenWithinDrive = FALSE,
#   .         canModifyContentRestriction = TRUE, canChangeSecurityUpdateEnabled = FALSE,
#   .         canAcceptOwnership = FALSE, canReadLabels = FALSE, canModifyLabels = FALSE,
#   .         canModifyEditorContentRestriction = TRUE, canModifyOwnerContentRestriction = TRUE,
#   .         canRemoveContentRestriction = FALSE, canDisableInheritedPermissions = FALSE,
#   .         canEnableInheritedPermissions = TRUE, canChangeItemDownloadRestriction = TRUE,
#   .         canStartApproval = FALSE), thumbnailVersion = "0", modifiedByMe = TRUE,
#   .     permissionIds = list("12963107500983395456"), linkShareMetadata = list(
#   .         securityUpdateEligible = FALSE, securityUpdateEnabled = TRUE),
#   .     sha1Checksum = "403abdbdcee950d239aa50896cff580456a83b71",
#   .     sha256Checksum = "fc6f1a6b9fbb8612f24cbb8e7dec08bdc5dacdb018355a0e857b322eaa4ed440",
#   .     inheritedPermissionsDisabled = FALSE, downloadRestrictions = list(
#   .         itemDownloadRestriction = list(restrictedForReaders = FALSE,
#   .             restrictedForWriters = FALSE), effectiveDownloadRestrictionWithContext = list(
#   .             restrictedForReaders = FALSE, restrictedForWriters = FALSE)),
#   .     clientEncryptionDetails = list(decryptionMetadata = list(
#   .         wrappedKey = "", kaclsId = "0", aes256GcmChunkSize = "unset",
#   .         keyFormat = "unsetKeyFormat", encryptionResourceKeyHash = ""))),
#   .     list(kind = "drive#file", copyRequiresWriterPermission = FALSE,
#   .         writersCanShare = TRUE, viewedByMe = TRUE, mimeType = "application/vnd.google-apps.folder",
#   .         parents = list("0AN88eXyT-r3yUk9PVA"), iconLink = "https://drive-thirdparty.googleusercontent.com/16/type/application/vnd.google-apps.folder",
#   .         shared = FALSE, lastModifyingUser = list(displayName = "Logiha Thayaparan",
#   .             kind = "drive#user", me = TRUE, permissionId = "12963107500983395456",
#   .             emailAddress = "logiha.thayaparan28@gmail.com", photoLink = "https://lh3.googleusercontent.com/a/ACg8ocJERnztX66xHnGkqf1LP4CPdrlXOOeTEBjjF-eRuw7F1sQGbQ=s64"),
#   .         owners = list(list(displayName = "Logiha Thayaparan",
#   .             kind = "drive#user", me = TRUE, permissionId = "12963107500983395456",
#   .             emailAddress = "logiha.thayaparan28@gmail.com", photoLink = "https://lh3.googleusercontent.com/a/ACg8ocJERnztX66xHnGkqf1LP4CPdrlXOOeTEBjjF-eRuw7F1sQGbQ=s64")),
#   .         webViewLink = "https://drive.google.com/drive/folders/1MnpVqF9-OTS-T4xVwoxp93pYPYKjo2SX",
#   .         viewersCanCopyContent = TRUE, permissions = list(list(
#   .             id = "12963107500983395456", displayName = "Logiha Thayaparan",
#   .             type = "user", kind = "drive#permission", photoLink = "https://lh3.googleusercontent.com/a/ACg8ocJERnztX66xHnGkqf1LP4CPdrlXOOeTEBjjF-eRuw7F1sQGbQ=s64",
#   .             emailAddress = "logiha.thayaparan28@gmail.com", role = "owner",
#   .             deleted = FALSE, pendingOwner = FALSE)), hasThumbnail = FALSE,
#   .         spaces = list("drive"), folderColorRgb = "#8f8f8f", id = "1MnpVqF9-OTS-T4xVwoxp93pYPYKjo2SX",
#   .         name = "NorthStar_dataset", starred = FALSE, trashed = FALSE,
#   .         explicitlyTrashed = FALSE, createdTime = "2026-05-23T12:29:33.962Z",
#   .         modifiedTime = "2026-05-23T12:29:33.962Z", modifiedByMeTime = "2026-05-23T12:29:33.962Z",
#   .         viewedByMeTime = "2026-05-23T12:31:48.902Z", quotaBytesUsed = "0",
#   .         version = "3", ownedByMe = TRUE, isAppAuthorized = FALSE,
#   .         capabilities = list(canChangeViewersCanCopyContent = FALSE,
#   .             canEdit = TRUE, canCopy = FALSE, canComment = TRUE,
#   .             canAddChildren = TRUE, canDelete = TRUE, canDownload = TRUE,
#   .             canListChildren = TRUE, canRemoveChildren = TRUE,
#   .             canRename = TRUE, canTrash = TRUE, canReadRevisions = FALSE,
#   .             canChangeCopyRequiresWriterPermission = FALSE, canMoveItemIntoTeamDrive = TRUE,
#   .             canUntrash = TRUE, canModifyContent = TRUE, canMoveItemOutOfDrive = TRUE,
#   .             canAddMyDriveParent = FALSE, canRemoveMyDriveParent = TRUE,
#   .             canMoveItemWithinDrive = TRUE, canShare = TRUE, canMoveChildrenWithinDrive = TRUE,
#   .             canModifyContentRestriction = FALSE, canChangeSecurityUpdateEnabled = FALSE,
#   .             canAcceptOwnership = FALSE, canReadLabels = FALSE,
#   .             canModifyLabels = FALSE, canModifyEditorContentRestriction = FALSE,
#   .             canModifyOwnerContentRestriction = FALSE, canRemoveContentRestriction = FALSE,
#   .             canDisableInheritedPermissions = TRUE, canEnableInheritedPermissions = TRUE,
#   .             canChangeItemDownloadRestriction = FALSE, canStartApproval = FALSE),
#   .         thumbnailVersion = "0", modifiedByMe = TRUE, permissionIds = list(
#   .             "12963107500983395456"), linkShareMetadata = list(
#   .             securityUpdateEligible = FALSE, securityUpdateEnabled = TRUE),
#   .         inheritedPermissionsDisabled = FALSE, downloadRestrictions = list(
#   .             itemDownloadRestriction = list(restrictedForReaders = FALSE,
#   .                 restrictedForWriters = FALSE), effectiveDownloadRestrictionWithContext = list(
#   .                 restrictedForReaders = FALSE, restrictedForWriters = FALSE)),
#   .         clientEncryptionDetails = list(decryptionMetadata = structure(list(), names = character(0)))),
#   .     list(kind = "drive#file", fileExtension = "csv", copyRequiresWriterPermission = FALSE,
#   .         md5Checksum = "c1cda283bcdf07b8088befbeca55a26e", writersCanShare = TRUE,
#   .         viewedByMe = TRUE, mimeType = "text/csv", parents = list(
#   .             "1MnpVqF9-OTS-T4xVwoxp93pYPYKjo2SX"), iconLink = "https://drive-thirdparty.googleusercontent.com/16/type/text/csv",
#   .         shared = FALSE, lastModifyingUser = list(displayName = "Logiha Thayaparan",
#   .             kind = "drive#user", me = TRUE, permissionId = "12963107500983395456",
#   .             emailAddress = "logiha.thayaparan28@gmail.com", photoLink = "https://lh3.googleusercontent.com/a/ACg8ocJERnztX66xHnGkqf1LP4CPdrlXOOeTEBjjF-eRuw7F1sQGbQ=s64"),
#   .         owners = list(list(displayName = "Logiha Thayaparan",
#   .             kind = "drive#user", me = TRUE, permissionId = "12963107500983395456",
#   .             emailAddress = "logiha.thayaparan28@gmail.com", photoLink = "https://lh3.googleusercontent.com/a/ACg8ocJERnztX66xHnGkqf1LP4CPdrlXOOeTEBjjF-eRuw7F1sQGbQ=s64")),
#   .         headRevisionId = "0B988eXyT-r3yQ1paQVNCdEF3bXdET05GbFl2ZEhkcU5hYzQ4PQ",
#   .         webViewLink = "https://drive.google.com/file/d/1xPkGKGv-ZQj8ZbvFksgZ4uQYNTU8dTH7/view?usp=drivesdk",
#   .         webContentLink = "https://drive.google.com/uc?id=1xPkGKGv-ZQj8ZbvFksgZ4uQYNTU8dTH7&export=download",
#   .         size = "7587", viewersCanCopyContent = TRUE, permissions = list(
#   .             list(id = "12963107500983395456", displayName = "Logiha Thayaparan",
#   .                 type = "user", kind = "drive#permission", photoLink = "https://lh3.googleusercontent.com/a/ACg8ocJERnztX66xHnGkqf1LP4CPdrlXOOeTEBjjF-eRuw7F1sQGbQ=s64",
#   .                 emailAddress = "logiha.thayaparan28@gmail.com",
#   .                 role = "owner", deleted = FALSE, pendingOwner = FALSE)),
#   .         hasThumbnail = FALSE, spaces = list("drive"), id = "1xPkGKGv-ZQj8ZbvFksgZ4uQYNTU8dTH7",
#   .         name = "vehicles.csv", starred = FALSE, trashed = FALSE,
#   .         explicitlyTrashed = FALSE, createdTime = "2026-05-23T12:20:15.794Z",
#   .         modifiedTime = "2026-03-15T14:47:48.000Z", modifiedByMeTime = "2026-03-15T14:47:48.000Z",
#   .         viewedByMeTime = "2026-05-23T12:20:15.794Z", quotaBytesUsed = "7587",
#   .         version = "3", originalFilename = "vehicles.csv", ownedByMe = TRUE,
#   .         fullFileExtension = "csv", isAppAuthorized = FALSE, capabilities = list(
#   .             canChangeViewersCanCopyContent = TRUE, canEdit = TRUE,
#   .             canCopy = TRUE, canComment = TRUE, canAddChildren = FALSE,
#   .             canDelete = TRUE, canDownload = TRUE, canListChildren = FALSE,
#   .             canRemoveChildren = FALSE, canRename = TRUE, canTrash = TRUE,
#   .             canReadRevisions = TRUE, canChangeCopyRequiresWriterPermission = TRUE,
#   .             canMoveItemIntoTeamDrive = TRUE, canUntrash = TRUE,
#   .             canModifyContent = TRUE, canMoveItemOutOfDrive = TRUE,
#   .             canAddMyDriveParent = FALSE, canRemoveMyDriveParent = TRUE,
#   .             canMoveItemWithinDrive = TRUE, canShare = TRUE, canMoveChildrenWithinDrive = FALSE,
#   .             canModifyContentRestriction = TRUE, canChangeSecurityUpdateEnabled = FALSE,
#   .             canAcceptOwnership = FALSE, canReadLabels = FALSE,
#   .             canModifyLabels = FALSE, canModifyEditorContentRestriction = TRUE,
#   .             canModifyOwnerContentRestriction = TRUE, canRemoveContentRestriction = FALSE,
#   .             canDisableInheritedPermissions = FALSE, canEnableInheritedPermissions = TRUE,
#   .             canChangeItemDownloadRestriction = TRUE, canStartApproval = FALSE),
#   .         thumbnailVersion = "0", modifiedByMe = TRUE, permissionIds = list(
#   .             "12963107500983395456"), linkShareMetadata = list(
#   .             securityUpdateEligible = FALSE, securityUpdateEnabled = TRUE),
#   .         sha1Checksum = "2702e7103dafb6471a935474ba833e95ea4624f7",
#   .         sha256Checksum = "5483e1f156c0e350f1f74c3994de798e5df6f0ae8a4e60a56a591e2757377b45",
#   .         inheritedPermissionsDisabled = FALSE, downloadRestrictions = list(
#   .             itemDownloadRestriction = list(restrictedForReaders = FALSE,
#   .                 restrictedForWriters = FALSE), effectiveDownloadRestrictionWithContext = list(
#   .                 restrictedForReaders = FALSE, restrictedForWriters = FALSE)),
#   .         clientEncryptionDetails = list(decryptionMetadata = list(
#   .             wrappedKey = "", kaclsId = "0", aes256GcmChunkSize = "unset",
#   .             keyFormat = "unsetKeyFormat", encryptionResourceKeyHash = ""))),
#   .     list(kind = "drive#file", fileExtension = "csv", copyRequiresWriterPermission = FALSE,
#   .         md5Checksum = "886c42c22ffb4b505bef60b580e6903b", writersCanShare = TRUE,
#   .         viewedByMe = TRUE, mimeType = "text/csv", parents = list(
#   .             "1MnpVqF9-OTS-T4xVwoxp93pYPYKjo2SX"), thumbnailLink = "https://lh3.googleusercontent.com/drive-storage/AJQWtBOJqltTBL4PuwVy0t0k9PtsGaEAHvYnb0JKu9Wt_fGNSxKQBcBY4pKw_vMueei60NZ5rmAoXWOk1O39Ky9QK7QL2XqNc8Lne1xNw8xlkl7S5teSzQ=s220",
#   .         iconLink = "https://drive-thirdparty.googleusercontent.com/16/type/text/csv",
#   .         shared = FALSE, lastModifyingUser = list(displayName = "Logiha Thayaparan",
#   .             kind = "drive#user", me = TRUE, permissionId = "12963107500983395456",
#   .             emailAddress = "logiha.thayaparan28@gmail.com", photoLink = "https://lh3.googleusercontent.com/a/ACg8ocJERnztX66xHnGkqf1LP4CPdrlXOOeTEBjjF-eRuw7F1sQGbQ=s64"),
#   .         owners = list(list(displayName = "Logiha Thayaparan",
#   .             kind = "drive#user", me = TRUE, permissionId = "12963107500983395456",
#   .             emailAddress = "logiha.thayaparan28@gmail.com", photoLink = "https://lh3.googleusercontent.com/a/ACg8ocJERnztX66xHnGkqf1LP4CPdrlXOOeTEBjjF-eRuw7F1sQGbQ=s64")),
#   .         headRevisionId = "0B988eXyT-r3ySE13c2hsOU81ajBqVFIwTHl4RlNEaG9mNnRnPQ",
#   .         webViewLink = "https://drive.google.com/file/d/1nQ_z6NFzhicxOHKsqEaOgFzCo7ODMuWX/view?usp=drivesdk",
#   .         webContentLink = "https://drive.google.com/uc?id=1nQ_z6NFzhicxOHKsqEaOgFzCo7ODMuWX&export=download",
#   .         size = "98155", viewersCanCopyContent = TRUE, permissions = list(
#   .             list(id = "12963107500983395456", displayName = "Logiha Thayaparan",
#   .                 type = "user", kind = "drive#permission", photoLink = "https://lh3.googleusercontent.com/a/ACg8ocJERnztX66xHnGkqf1LP4CPdrlXOOeTEBjjF-eRuw7F1sQGbQ=s64",
#   .                 emailAddress = "logiha.thayaparan28@gmail.com",
#   .                 role = "owner", deleted = FALSE, pendingOwner = FALSE)),
#   .         hasThumbnail = TRUE, spaces = list("drive"), id = "1nQ_z6NFzhicxOHKsqEaOgFzCo7ODMuWX",
#   .         name = "deliveries.csv", starred = FALSE, trashed = FALSE,
#   .         explicitlyTrashed = FALSE, createdTime = "2026-05-23T12:20:15.670Z",
#   .         modifiedTime = "2026-03-15T14:47:48.000Z", modifiedByMeTime = "2026-03-15T14:47:48.000Z",
#   .         viewedByMeTime = "2026-05-23T12:20:15.670Z", quotaBytesUsed = "98155",
#   .         version = "4", originalFilename = "deliveries.csv", ownedByMe = TRUE,
#   .         fullFileExtension = "csv", isAppAuthorized = FALSE, capabilities = list(
#   .             canChangeViewersCanCopyContent = TRUE, canEdit = TRUE,
#   .             canCopy = TRUE, canComment = TRUE, canAddChildren = FALSE,
#   .             canDelete = TRUE, canDownload = TRUE, canListChildren = FALSE,
#   .             canRemoveChildren = FALSE, canRename = TRUE, canTrash = TRUE,
#   .             canReadRevisions = TRUE, canChangeCopyRequiresWriterPermission = TRUE,
#   .             canMoveItemIntoTeamDrive = TRUE, canUntrash = TRUE,
#   .             canModifyContent = TRUE, canMoveItemOutOfDrive = TRUE,
#   .             canAddMyDriveParent = FALSE, canRemoveMyDriveParent = TRUE,
#   .             canMoveItemWithinDrive = TRUE, canShare = TRUE, canMoveChildrenWithinDrive = FALSE,
#   .             canModifyContentRestriction = TRUE, canChangeSecurityUpdateEnabled = FALSE,
#   .             canAcceptOwnership = FALSE, canReadLabels = FALSE,
#   .             canModifyLabels = FALSE, canModifyEditorContentRestriction = TRUE,
#   .             canModifyOwnerContentRestriction = TRUE, canRemoveContentRestriction = FALSE,
#   .             canDisableInheritedPermissions = FALSE, canEnableInheritedPermissions = TRUE,
#   .             canChangeItemDownloadRestriction = TRUE, canStartApproval = FALSE),
#   .         thumbnailVersion = "1", modifiedByMe = TRUE, permissionIds = list(
#   .             "12963107500983395456"), linkShareMetadata = list(
#   .             securityUpdateEligible = FALSE, securityUpdateEnabled = TRUE),
#   .         sha1Checksum = "93bd357e8290571c61c1d653f3db084fddfccf01",
#   .         sha256Checksum = "89fcf2eeb23d742b883583e4a69e56e86b136ce7a01dbfefdc6f644dd9d844ee",
#   .         inheritedPermissionsDisabled = FALSE, downloadRestrictions = list(
#   .             itemDownloadRestriction = list(restrictedForReaders = FALSE,
#   .                 restrictedForWriters = FALSE), effectiveDownloadRestrictionWithContext = list(
#   .                 restrictedForReaders = FALSE, restrictedForWriters = FALSE)),
#   .         clientEncryptionDetails = list(decryptionMetadata = list(
#   .             wrappedKey = "", kaclsId = "0", aes256GcmChunkSize = "unset",
#   .             keyFormat = "unsetKeyFormat", encryptionResourceKeyHash = ""))),
#   .     list(kind = "drive#file", fileExtension = "csv", copyRequiresWriterPermission = FALSE,
#   .         md5Checksum = "dea988c7b611280c61ca44f8d21684ed", writersCanShare = TRUE,
#   .         viewedByMe = TRUE, mimeType = "text/csv", parents = list(
#   .             "1MnpVqF9-OTS-T4xVwoxp93pYPYKjo2SX"), iconLink = "https://drive-thirdparty.googleusercontent.com/16/type/text/csv",
#   .         shared = FALSE, lastModifyingUser = list(displayName = "Logiha Thayaparan",
#   .             kind = "drive#user", me = TRUE, permissionId = "12963107500983395456",
#   .             emailAddress = "logiha.thayaparan28@gmail.com", photoLink = "https://lh3.googleusercontent.com/a/ACg8ocJERnztX66xHnGkqf1LP4CPdrlXOOeTEBjjF-eRuw7F1sQGbQ=s64"),
#   .         owners = list(list(displayName = "Logiha Thayaparan",
#   .             kind = "drive#user", me = TRUE, permissionId = "12963107500983395456",
#   .             emailAddress = "logiha.thayaparan28@gmail.com", photoLink = "https://lh3.googleusercontent.com/a/ACg8ocJERnztX66xHnGkqf1LP4CPdrlXOOeTEBjjF-eRuw7F1sQGbQ=s64")),
#   .         headRevisionId = "0B988eXyT-r3yQlp5MTlrZDlEVmc2bnBEWGRTRS91TlJXVDlBPQ",
#   .         webViewLink = "https://drive.google.com/file/d/1oP8VFt-8pfd2-fe71m9y9u4jihGBFsLc/view?usp=drivesdk",
#   .         webContentLink = "https://drive.google.com/uc?id=1oP8VFt-8pfd2-fe71m9y9u4jihGBFsLc&export=download",
#   .         size = "42712", viewersCanCopyContent = TRUE, permissions = list(
#   .             list(id = "12963107500983395456", displayName = "Logiha Thayaparan",
#   .                 type = "user", kind = "drive#permission", photoLink = "https://lh3.googleusercontent.com/a/ACg8ocJERnztX66xHnGkqf1LP4CPdrlXOOeTEBjjF-eRuw7F1sQGbQ=s64",
#   .                 emailAddress = "logiha.thayaparan28@gmail.com",
#   .                 role = "owner", deleted = FALSE, pendingOwner = FALSE)),
#   .         hasThumbnail = FALSE, spaces = list("drive"), id = "1oP8VFt-8pfd2-fe71m9y9u4jihGBFsLc",
#   .         name = "customers.csv", starred = FALSE, trashed = FALSE,
#   .         explicitlyTrashed = FALSE, createdTime = "2026-05-23T12:20:15.587Z",
#   .         modifiedTime = "2026-03-15T14:47:48.000Z", modifiedByMeTime = "2026-03-15T14:47:48.000Z",
#   .         viewedByMeTime = "2026-05-23T12:20:15.587Z", quotaBytesUsed = "42712",
#   .         version = "3", originalFilename = "customers.csv", ownedByMe = TRUE,
#   .         fullFileExtension = "csv", isAppAuthorized = FALSE, capabilities = list(
#   .             canChangeViewersCanCopyContent = TRUE, canEdit = TRUE,
#   .             canCopy = TRUE, canComment = TRUE, canAddChildren = FALSE,
#   .             canDelete = TRUE, canDownload = TRUE, canListChildren = FALSE,
#   .             canRemoveChildren = FALSE, canRename = TRUE, canTrash = TRUE,
#   .             canReadRevisions = TRUE, canChangeCopyRequiresWriterPermission = TRUE,
#   .             canMoveItemIntoTeamDrive = TRUE, canUntrash = TRUE,
#   .             canModifyContent = TRUE, canMoveItemOutOfDrive = TRUE,
#   .             canAddMyDriveParent = FALSE, canRemoveMyDriveParent = TRUE,
#   .             canMoveItemWithinDrive = TRUE, canShare = TRUE, canMoveChildrenWithinDrive = FALSE,
#   .             canModifyContentRestriction = TRUE, canChangeSecurityUpdateEnabled = FALSE,
#   .             canAcceptOwnership = FALSE, canReadLabels = FALSE,
#   .             canModifyLabels = FALSE, canModifyEditorContentRestriction = TRUE,
#   .             canModifyOwnerContentRestriction = TRUE, canRemoveContentRestriction = FALSE,
#   .             canDisableInheritedPermissions = FALSE, canEnableInheritedPermissions = TRUE,
#   .             canChangeItemDownloadRestriction = TRUE, canStartApproval = FALSE),
#   .         thumbnailVersion = "0", modifiedByMe = TRUE, permissionIds = list(
#   .             "12963107500983395456"), linkShareMetadata = list(
#   .             securityUpdateEligible = FALSE, securityUpdateEnabled = TRUE),
#   .         sha1Checksum = "ff5b6b008206b3ee12fd1d04821227600b315e0b",
#   .         sha256Checksum = "b8abfb6dedd14a73d9bd3cc0cc7b840108c3d25e6540a6054a34dc50e3b9432b",
#   .         inheritedPermissionsDisabled = FALSE, downloadRestrictions = list(
#   .             itemDownloadRestriction = list(restrictedForReaders = FALSE,
#   .                 restrictedForWriters = FALSE), effectiveDownloadRestrictionWithContext = list(
#   .                 restrictedForReaders = FALSE, restrictedForWriters = FALSE)),
#   .         clientEncryptionDetails = list(decryptionMetadata = list(
#   .             wrappedKey = "", kaclsId = "0", aes256GcmChunkSize = "unset",
#   .             keyFormat = "unsetKeyFormat", encryptionResourceKeyHash = ""))),
#   .     check.names = FALSE, fix.empty.names = TRUE, stringsAsFactors = FALSE)
# 24. as.data.frame(x[[i]], optional = TRUE, stringsAsFactors = stringsAsFactors)
# 25. as.data.frame.list(x[[i]], optional = TRUE, stringsAsFactors = stringsAsFactors)
# 26. do.call(data.frame, c(x, alis))
# 27. (function (..., row.names = NULL, check.rows = FALSE, check.names = TRUE,
#   .     fix.empty.names = TRUE, stringsAsFactors = FALSE)
#   . {
#   .     data.row.names <- if (check.rows && is.null(row.names))
#   .         function(current, new, i) {
#   .             if (is.character(current))
#   .                 new <- as.character(new)
#   .             if (is.character(new))
#   .                 current <- as.character(current)
#   .             if (anyDuplicated(new))
#   .                 return(current)
#   .             if (is.null(current))
#   .                 return(new)
#   .             if (all(current == new) || all(current == ""))
#   .                 return(new)
#   .             stop(gettextf("mismatch of row names in arguments of 'data.frame', item %d",
#   .                 i), domain = NA)
#   .         }
#   .     else function(current, new, i) {
#   .         current %||% if (anyDuplicated(new)) {
#   .             warning(gettextf("some row.names duplicated: %s --> row.names NOT used",
#   .                 paste(which(duplicated(new)), collapse = ",")),
#   .                 domain = NA)
#   .             current
#   .         }
#   .         else new
#   .     }
#   .     object <- as.list(substitute(list(...)))[-1L]
#   .     mirn <- missing(row.names)
#   .     mrn <- is.null(row.names)
#   .     x <- list(...)
#   .     n <- length(x)
#   .     if (n < 1L) {
#   .         if (!mrn) {
#   .             if (is.object(row.names) || !is.integer(row.names))
#   .                 row.names <- as.character(row.names)
#   .             if (anyNA(row.names))
#   .                 stop("row names contain missing values")
#   .             if (anyDuplicated(row.names))
#   .                 stop(gettextf("duplicate row.names: %s", paste(unique(row.names[duplicated(row.names)]),
#   .                   collapse = ", ")), domain = NA)
#   .         }
#   .         else row.names <- integer()
#   .         return(structure(list(), names = character(), row.names = row.names,
#   .             class = "data.frame"))
#   .     }
#   .     vnames <- names(x)
#   .     if (length(vnames) != n)
#   .         vnames <- character(n)
#   .     no.vn <- !nzchar(vnames)
#   .     vlist <- vnames <- as.list(vnames)
#   .     nrows <- ncols <- integer(n)
#   .     for (i in seq_len(n)) {
#   .         xi <- if (is.character(x[[i]]) || is.list(x[[i]]))
#   .             as.data.frame(x[[i]], optional = TRUE, stringsAsFactors = stringsAsFactors)
#   .         else as.data.frame(x[[i]], optional = TRUE)
#   .         nrows[i] <- .row_names_info(xi)
#   .         ncols[i] <- length(xi)
#   .         namesi <- names(xi)
#   .         if (ncols[i] > 1L) {
#   .             if (length(namesi) == 0L)
#   .                 namesi <- seq_len(ncols[i])
#   .             vnames[[i]] <- if (no.vn[i])
#   .                 namesi
#   .             else paste(vnames[[i]], namesi, sep = ".")
#   .         }
#   .         else if (length(namesi)) {
#   .             vnames[[i]] <- namesi
#   .         }
#   .         else if (fix.empty.names && no.vn[[i]]) {
#   .             tmpname <- deparse(object[[i]], nlines = 1L)[1L]
#   .             if (startsWith(tmpname, "I(") && endsWith(tmpname,
#   .                 ")")) {
#   .                 ntmpn <- nchar(tmpname, "c")
#   .                 tmpname <- substr(tmpname, 3L, ntmpn - 1L)
#   .             }
#   .             vnames[[i]] <- tmpname
#   .         }
#   .         if (mirn && nrows[i] > 0L) {
#   .             rowsi <- attr(xi, "row.names")
#   .             if (any(nzchar(rowsi)))
#   .                 row.names <- data.row.names(row.names, rowsi,
#   .                   i)
#   .         }
#   .         nrows[i] <- abs(nrows[i])
#   .         vlist[[i]] <- xi
#   .     }
#   .     nr <- max(nrows)
#   .     for (i in seq_len(n)[nrows < nr]) {
#   .         xi <- vlist[[i]]
#   .         if (nrows[i] > 0L && (nr%%nrows[i] == 0L)) {
#   .             xi <- unclass(xi)
#   .             fixed <- TRUE
#   .             for (j in seq_along(xi)) {
#   .                 xi1 <- xi[[j]]
#   .                 if (is.vector(xi1) || is.factor(xi1))
#   .                   xi[[j]] <- rep(xi1, length.out = nr)
#   .                 else if (is.character(xi1) && inherits(xi1, "AsIs"))
#   .                   xi[[j]] <- structure(rep(xi1, length.out = nr),
#   .                     class = class(xi1))
#   .                 else if (inherits(xi1, "Date") || inherits(xi1,
#   .                   "POSIXct"))
#   .                   xi[[j]] <- rep(xi1, length.out = nr)
#   .                 else {
#   .                   fixed <- FALSE
#   .                   break
#   .                 }
#   .             }
#   .             if (fixed) {
#   .                 vlist[[i]] <- xi
#   .                 next
#   .             }
#   .         }
#   .         stop(gettextf("arguments imply differing number of rows: %s",
#   .             paste(unique(nrows), collapse = ", ")), domain = NA)
#   .     }
#   .     value <- unlist(vlist, recursive = FALSE, use.names = FALSE)
#   .     vnames <- as.character(unlist(vnames[ncols > 0L]))
#   .     if (fix.empty.names && any(noname <- !nzchar(vnames)))
#   .         vnames[noname] <- paste0("Var.", seq_along(vnames))[noname]
#   .     if (check.names) {
#   .         if (fix.empty.names)
#   .             vnames <- make.names(vnames, unique = TRUE)
#   .         else {
#   .             nz <- nzchar(vnames)
#   .             vnames[nz] <- make.names(vnames[nz], unique = TRUE)
#   .         }
#   .     }
#   .     names(value) <- vnames
#   .     if (!mrn) {
#   .         if (length(row.names) == 1L && nr != 1L) {
#   .             if (is.character(row.names))
#   .                 row.names <- match(row.names, vnames, 0L)
#   .             if (length(row.names) != 1L || row.names < 1L ||
#   .                 row.names > length(vnames))
#   .                 stop("'row.names' should specify one of the variables")
#   .             i <- row.names
#   .             row.names <- value[[i]]
#   .             value <- value[-i]
#   .         }
#   .         else if (!is.null(row.names) && length(row.names) !=
#   .             nr)
#   .             stop("row names supplied are of the wrong length")
#   .     }
#   .     else if (!is.null(row.names) && length(row.names) != nr) {
#   .         warning("row names were found from a short variable and have been discarded")
#   .         row.names <- NULL
#   .     }
#   .     class(value) <- "data.frame"
#   .     if (is.null(row.names))
#   .         attr(value, "row.names") <- .set_row_names(nr)
#   .     else {
#   .         if (is.object(row.names) || !is.integer(row.names))
#   .             row.names <- as.character(row.names)
#   .         if (anyNA(row.names))
#   .             stop("row names contain missing values")
#   .         if (anyDuplicated(row.names))
#   .             stop(gettextf("duplicate row.names: %s", paste(unique(row.names[duplicated(row.names)]),
#   .                 collapse = ", ")), domain = NA)
#   .         row.names(value) <- row.names
#   .     }
#   .     value
#   . })(kind = "drive#file", copyRequiresWriterPermission = FALSE,
#   .     writersCanShare = TRUE, viewedByMe = TRUE, mimeType = "application/vnd.google-apps.folder",
#   .     parents = list("0AN88eXyT-r3yUk9PVA"), iconLink = "https://drive-thirdparty.googleusercontent.com/16/type/application/vnd.google-apps.folder",
#   .     shared = FALSE, lastModifyingUser = list(displayName = "Logiha Thayaparan",
#   .         kind = "drive#user", me = TRUE, permissionId = "12963107500983395456",
#   .         emailAddress = "logiha.thayaparan28@gmail.com", photoLink = "https://lh3.googleusercontent.com/a/ACg8ocJERnztX66xHnGkqf1LP4CPdrlXOOeTEBjjF-eRuw7F1sQGbQ=s64"),
#   .     owners = list(list(displayName = "Logiha Thayaparan", kind = "drive#user",
#   .         me = TRUE, permissionId = "12963107500983395456", emailAddress = "logiha.thayaparan28@gmail.com",
#   .         photoLink = "https://lh3.googleusercontent.com/a/ACg8ocJERnztX66xHnGkqf1LP4CPdrlXOOeTEBjjF-eRuw7F1sQGbQ=s64")),
#   .     webViewLink = "https://drive.google.com/drive/folders/1MnpVqF9-OTS-T4xVwoxp93pYPYKjo2SX",
#   .     viewersCanCopyContent = TRUE, permissions = list(list(id = "12963107500983395456",
#   .         displayName = "Logiha Thayaparan", type = "user", kind = "drive#permission",
#   .         photoLink = "https://lh3.googleusercontent.com/a/ACg8ocJERnztX66xHnGkqf1LP4CPdrlXOOeTEBjjF-eRuw7F1sQGbQ=s64",
#   .         emailAddress = "logiha.thayaparan28@gmail.com", role = "owner",
#   .         deleted = FALSE, pendingOwner = FALSE)), hasThumbnail = FALSE,
#   .     spaces = list("drive"), folderColorRgb = "#8f8f8f", id = "1MnpVqF9-OTS-T4xVwoxp93pYPYKjo2SX",
#   .     name = "NorthStar_dataset", starred = FALSE, trashed = FALSE,
#   .     explicitlyTrashed = FALSE, createdTime = "2026-05-23T12:29:33.962Z",
#   .     modifiedTime = "2026-05-23T12:29:33.962Z", modifiedByMeTime = "2026-05-23T12:29:33.962Z",
#   .     viewedByMeTime = "2026-05-23T12:31:48.902Z", quotaBytesUsed = "0",
#   .     version = "3", ownedByMe = TRUE, isAppAuthorized = FALSE,
#   .     capabilities = list(canChangeViewersCanCopyContent = FALSE,
#   .         canEdit = TRUE, canCopy = FALSE, canComment = TRUE, canAddChildren = TRUE,
#   .         canDelete = TRUE, canDownload = TRUE, canListChildren = TRUE,
#   .         canRemoveChildren = TRUE, canRename = TRUE, canTrash = TRUE,
#   .         canReadRevisions = FALSE, canChangeCopyRequiresWriterPermission = FALSE,
#   .         canMoveItemIntoTeamDrive = TRUE, canUntrash = TRUE, canModifyContent = TRUE,
#   .         canMoveItemOutOfDrive = TRUE, canAddMyDriveParent = FALSE,
#   .         canRemoveMyDriveParent = TRUE, canMoveItemWithinDrive = TRUE,
#   .         canShare = TRUE, canMoveChildrenWithinDrive = TRUE, canModifyContentRestriction = FALSE,
#   .         canChangeSecurityUpdateEnabled = FALSE, canAcceptOwnership = FALSE,
#   .         canReadLabels = FALSE, canModifyLabels = FALSE, canModifyEditorContentRestriction = FALSE,
#   .         canModifyOwnerContentRestriction = FALSE, canRemoveContentRestriction = FALSE,
#   .         canDisableInheritedPermissions = TRUE, canEnableInheritedPermissions = TRUE,
#   .         canChangeItemDownloadRestriction = FALSE, canStartApproval = FALSE),
#   .     thumbnailVersion = "0", modifiedByMe = TRUE, permissionIds = list(
#   .         "12963107500983395456"), linkShareMetadata = list(securityUpdateEligible = FALSE,
#   .         securityUpdateEnabled = TRUE), inheritedPermissionsDisabled = FALSE,
#   .     downloadRestrictions = list(itemDownloadRestriction = list(
#   .         restrictedForReaders = FALSE, restrictedForWriters = FALSE),
#   .         effectiveDownloadRestrictionWithContext = list(restrictedForReaders = FALSE,
#   .             restrictedForWriters = FALSE)), clientEncryptionDetails = list(
#   .         decryptionMetadata = structure(list(), names = character(0))),
#   .     check.names = FALSE, fix.empty.names = TRUE, stringsAsFactors = FALSE)
# 28. stop(gettextf("arguments imply differing number of rows: %s",
#   .     paste(unique(nrows), collapse = ", ")), domain = NA)

# %%
deliveries_file <- drive_get("NorthStar_dataset/deliveries.csv")
# Out:
# ✔ The input `path` resolved to exactly 1 file.

# %%
drive_download(
  deliveries_file,
  path = "deliveries.csv",
  overwrite = TRUE
)
# Out:
# File downloaded:
#
# • deliveries.csv <id: 1nQ_z6NFzhicxOHKsqEaOgFzCo7ODMuWX>
#
# Saved locally as:
#
# • deliveries.csv

# %%
deliveries <- read.csv("deliveries.csv")

head(deliveries)
# Out:
#   delivery_id order_id driver_id vehicle_id hub_id dispatch_time
# 1 DL00001     O00938   D004      V056       H05    2024-06-18 10:57:00
# 2 DL00002     O00004   D138      V007       H02    2025-01-11 18:45:00
# 3 DL00003     O00639   D006      V049       H02    2025-06-02 20:39:00
# 4 DL00004     O00313   D116      V055       H02    2024-03-08 23:31:00
# 5 DL00005     O00844   D108      V034       H01    2025-09-21 11:43:00
# 6 DL00006     O00029   D037      V098       H03    2024-09-11 12:40:00
#   delivery_completed_at      delivery_status route_distance_km
# 1 2024-06-19 09:05:59.904311 Failed          17.26
# 2 2025-01-11 17:39:00.000000 OnTime          10.34
# 3 2025-06-02 21:45:32.366770 OnTime           7.92
# 4 2024-03-09 23:30:08.103702 Delayed         16.42
# 5 2025-09-21 15:45:34.131056 OnTime          14.52
# 6 2024-09-12 17:11:52.384869 Delayed         13.84
#   manual_route_override_count proof_of_completion_missing
# 1 1                           0
# 2 1                           0
# 3 0                           0
# 4 0                           0
# 5 1                           0
# 6 0                           0
#   customer_rating_post_delivery fuel_or_charge_cost
# 1 3.07                          12.05
# 2 5.00                          13.41
# 3 4.98                           8.51
# 4 4.18                          13.62
# 5 4.18                           9.22
# 6 1.57                           9.58

# %%
install.packages("sqldf")
library(sqldf)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘gsubfn’, ‘proto’, ‘RSQLite’, ‘chron’
#
#
# Loading required package: gsubfn
#
# Loading required package: proto
#
# Warning message:
# “no DISPLAY variable so Tk is not available”
# Loading required package: RSQLite

# %%
sqldf("
SELECT delivery_status,
COUNT(*) AS total_deliveries
FROM deliveries
GROUP BY delivery_status
")
# Out:
#   delivery_status total_deliveries
# 1 Delayed         202
# 2 Failed          132
# 3 OnTime          616

# %%
complaints_file <- drive_get("NorthStar_dataset/complaints.csv")

drive_download(
  complaints_file,
  path = "complaints.csv",
  overwrite = TRUE
)

complaints <- read.csv("complaints.csv")

head(complaints)
# Out:
# ✔ The input `path` resolved to exactly 1 file.
#
# File downloaded:
#
# • complaints.csv <id: 1s46Ra8PsKZC83GmYuueEZoDtscon-RWv>
#
# Saved locally as:
#
# • complaints.csv
#   complaint_id customer_id order_id complaint_type channel severity
# 1 CP0001       C0464       O00814   AppIssue       App     High
# 2 CP0002       C0056       O00628   MissedPickup   Phone   Medium
# 3 CP0003       C0469       O00384   Delay          Chatbot High
# 4 CP0004       C0631       O00406   Delay          App     Medium
# 5 CP0005       C0535       O00154   Delay          Email   Medium
# 6 CP0006       C0096       O00147   Delay          App     Medium
#   created_at          status           resolution_days compensation_amount
# 1 2025-03-30 02:36:00 Open             11              23.99
# 2 2024-11-07 10:05:00 Open              4              21.64
# 3 2024-01-02 15:47:00 Open             16              26.41
# 4 2025-01-14 13:07:00 AwaitingCustomer  7              23.44
# 5 2024-08-31 05:56:00 Resolved          1              16.18
# 6 2024-07-22 07:43:00 Resolved          9              18.51

# %%
sqldf("
SELECT complaint_type,
COUNT(*) AS total_complaints
FROM complaints
GROUP BY complaint_type
ORDER BY total_complaints DESC
")
# Out:
#   complaint_type    total_complaints
# 1 Delay             101
# 2 MissedPickup       64
# 3 AppIssue           53
# 4 DriverBehaviour    51
# 5 SupportExperience  20
# 6 Billing            16
# 7 Damage             15

# %% [markdown]
# SQL analysis identified that delay-related complaints represented the highest category of customer dissatisfaction within NorthStar’s operational system

# %%
hubs_file <- drive_get("NorthStar_dataset/hubs.csv")

drive_download(
  hubs_file,
  path = "hubs.csv",
  overwrite = TRUE
)

hubs <- read.csv("hubs.csv")

head(hubs)
# Out:
# ✔ The input `path` resolved to exactly 1 file.
#
# File downloaded:
#
# • hubs.csv <id: 1Vd_-BdXYpn5InjU0pzOLQPuL5rOyjfhT>
#
# Saved locally as:
#
# • hubs.csv
#   hub_id hub_name       zone    hub_type  capacity_score
# 1 H01    North Exchange North   Dispatch  82
# 2 H02    South Link     South   Dispatch  78
# 3 H03    East Dock      East    Warehouse 74
# 4 H04    West Gate      West    Dispatch  69
# 5 H05    Central Core   Central Control   88
# 6 H06    Airport Hub    Airport Dispatch  71

# %%
sqldf("
SELECT h.zone,
COUNT(*) AS failed_deliveries

FROM deliveries d

JOIN hubs h
ON d.hub_id = h.hub_id

WHERE d.delivery_status = 'Failed'

GROUP BY h.zone

ORDER BY failed_deliveries DESC
")
# Out:
#   zone      failed_deliveries
# 1 Central   49
# 2 North     17
# 3 West      16
# 4 Airport   15
# 5 Riverside 14
# 6 East      11
# 7 South     10

# %%
install.packages("sqldf")

library(sqldf)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘gsubfn’, ‘proto’, ‘RSQLite’, ‘chron’
#
#
# Loading required package: gsubfn
#
# Loading required package: proto
#
# Warning message:
# “no DISPLAY variable so Tk is not available”
# Loading required package: RSQLite

# %%
library(googledrive)

deliveries_file <- drive_get("NorthStar_dataset/deliveries.csv")

drive_download(
  deliveries_file,
  path = "deliveries.csv",
  overwrite = TRUE
)

deliveries <- read.csv("deliveries.csv")

head(deliveries)
# Out:
# Is it OK to cache OAuth access credentials in the folder ~/.cache/gargle
# between R sessions?
# 1: Yes
# 2: No
# Selection: 1
# Please point your browser to the following url:
#
# https://accounts.google.com/o/oauth2/v2/auth?client_id=603366585132-frjlouoa3s2ono25d2l9ukvhlsrlnr7k.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email&redirect_uri=https%3A%2F%2Fwww.tidyverse.org%2Fgoogle-callback%2F&response_type=code&state=44c1618c9cb14aeb04eac36492c665a6&access_type=offline&prompt=consent
# Enter authorization code: eyJjb2RlIjoiNC8wQWVvV3VNOWcxSEFYMGx0dzhmSlpSTmdfUnhiZTBuWmNGR3Yzam5BWHhZenlJVlhnNzRaeWN3TmE5UVNFcFNVWDNNc0NYZyIsInN0YXRlIjoiNDRjMTYxOGM5Y2IxNGFlYjA0ZWFjMzY0OTJjNjY1YTYifQ==
# ✔ The input `path` resolved to exactly 1 file.
#
# File downloaded:
#
# • deliveries.csv <id: 1nQ_z6NFzhicxOHKsqEaOgFzCo7ODMuWX>
#
# Saved locally as:
#
# • deliveries.csv
#   delivery_id order_id driver_id vehicle_id hub_id dispatch_time
# 1 DL00001     O00938   D004      V056       H05    2024-06-18 10:57:00
# 2 DL00002     O00004   D138      V007       H02    2025-01-11 18:45:00
# 3 DL00003     O00639   D006      V049       H02    2025-06-02 20:39:00
# 4 DL00004     O00313   D116      V055       H02    2024-03-08 23:31:00
# 5 DL00005     O00844   D108      V034       H01    2025-09-21 11:43:00
# 6 DL00006     O00029   D037      V098       H03    2024-09-11 12:40:00
#   delivery_completed_at      delivery_status route_distance_km
# 1 2024-06-19 09:05:59.904311 Failed          17.26
# 2 2025-01-11 17:39:00.000000 OnTime          10.34
# 3 2025-06-02 21:45:32.366770 OnTime           7.92
# 4 2024-03-09 23:30:08.103702 Delayed         16.42
# 5 2025-09-21 15:45:34.131056 OnTime          14.52
# 6 2024-09-12 17:11:52.384869 Delayed         13.84
#   manual_route_override_count proof_of_completion_missing
# 1 1                           0
# 2 1                           0
# 3 0                           0
# 4 0                           0
# 5 1                           0
# 6 0                           0
#   customer_rating_post_delivery fuel_or_charge_cost
# 1 3.07                          12.05
# 2 5.00                          13.41
# 3 4.98                           8.51
# 4 4.18                          13.62
# 5 4.18                           9.22
# 6 1.57                           9.58

# %%
library(sqldf)

sqldf("
SELECT delivery_status,
AVG(customer_rating_post_delivery) AS average_rating
FROM deliveries
GROUP BY delivery_status
")
# Out:
#   delivery_status average_rating
# 1 Delayed         3.114975
# 2 Failed          3.049313
# 3 OnTime          4.283273

# %% [markdown]
# The SQL analysis shows that delivery performance has a strong impact on customer satisfaction. Deliveries completed on time received the highest average customer rating of 4.28, while delayed and failed deliveries received much lower ratings of 3.11 and 3.04. This suggests that delays and failed deliveries negatively affect customer experience and reduce the overall service quality within NorthStar’s logistics operations.

# %%
sqldf("
SELECT delivery_status,
AVG(manual_route_override_count) AS average_override
FROM deliveries
GROUP BY delivery_status
")
# Out:
#   delivery_status average_override
# 1 Delayed         1.0742574
# 2 Failed          1.0378788
# 3 OnTime          0.9204545

# %% [markdown]
# The SQL analysis shows that failed and delayed deliveries had higher average manual route override counts compared to deliveries completed on time. This suggests that drivers are more likely to change routes manually during problematic deliveries. The findings may indicate issues such as poor route planning, traffic problems or operational efforts to manage delivery targets. Overall, the results support management concerns about route allocation inefficiencies within NorthStar’s operational network.

# %%
sqldf("
SELECT hub_id,
AVG(fuel_or_charge_cost) AS average_cost
FROM deliveries
GROUP BY hub_id
ORDER BY average_cost DESC
")
# Out:
#   hub_id average_cost
# 1 H05    13.68600
# 2 H06    13.31923
# 3 H04    13.16701
# 4 H07    12.92209
# 5 H01    12.75581
# 6 H03    12.74420
# 7 H02    12.56500
# 8 H08    11.70820

# %% [markdown]
# The SQL analysis showed differences in average fuel and charging costs between operational hubs. Hub H05 had the highest average operational cost, while H08 had the lowest. These differences may indicate issues such as inefficient vehicle allocation, higher charging requirements or increased operational expenses at certain hubs. The findings also support management concerns about rising operational costs and inconsistent performance across NorthStar’s logistics network.

# %%
hubs_file <- drive_get("NorthStar_dataset/hubs.csv")

drive_download(
  hubs_file,
  path = "hubs.csv",
  overwrite = TRUE
)

hubs <- read.csv("hubs.csv")

head(hubs)
# Out:
# ✔ The input `path` resolved to exactly 1 file.
#
# File downloaded:
#
# • hubs.csv <id: 1Vd_-BdXYpn5InjU0pzOLQPuL5rOyjfhT>
#
# Saved locally as:
#
# • hubs.csv
#   hub_id hub_name       zone    hub_type  capacity_score
# 1 H01    North Exchange North   Dispatch  82
# 2 H02    South Link     South   Dispatch  78
# 3 H03    East Dock      East    Warehouse 74
# 4 H04    West Gate      West    Dispatch  69
# 5 H05    Central Core   Central Control   88
# 6 H06    Airport Hub    Airport Dispatch  71

# %%
sqldf("
SELECT h.zone,
COUNT(*) AS total_delayed

FROM deliveries d

JOIN hubs h
ON d.hub_id = h.hub_id

WHERE d.delivery_status = 'Delayed'

GROUP BY h.zone

ORDER BY total_delayed DESC
")
# Out:
#   zone      total_delayed
# 1 Central   47
# 2 West      28
# 3 Airport   27
# 4 South     26
# 5 North     26
# 6 Riverside 25
# 7 East      23

# %% [markdown]
# The SQL JOIN analysis shows that the Central zone had the highest number of delayed deliveries, with 47 delayed cases recorded. This supports the earlier Python analysis, where the Central zone also had the highest number of failed deliveries. The repeated results suggest that issues such as route congestion, heavy hub workload or poor operational planning may be more common in the Central area.

# %%
install.packages("sqldf")

library(sqldf)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘gsubfn’, ‘proto’, ‘RSQLite’, ‘chron’
#
#
# Loading required package: gsubfn
#
# Loading required package: proto
#
# Warning message:
# “no DISPLAY variable so Tk is not available”
# Loading required package: RSQLite

# %%
library(googledrive)

drive_deauth()

drive_auth(
  scopes = "https://www.googleapis.com/auth/drive"
)
# Out:
# The googledrive package is requesting access to your Google account.
# Enter '1' to start a new auth process or select a pre-authorized account.
# 1: Send me to the browser for a new auth process.
# 2: logihathayaparan@gmail.com
# Selection: 1
# Please point your browser to the following url:
#
# https://accounts.google.com/o/oauth2/v2/auth?client_id=603366585132-frjlouoa3s2ono25d2l9ukvhlsrlnr7k.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email&redirect_uri=https%3A%2F%2Fwww.tidyverse.org%2Fgoogle-callback%2F&response_type=code&state=dd80289484f5e46b47128bce614843c2&access_type=offline&prompt=consent
# Enter authorization code: eyJjb2RlIjoiNC8wQWVvV3VNOEVRYmpmX2xPUHFkOGtQZ1k2RURieEdyYkdwdkpMTnhoSHkxalRjZ2FzTTVFMndhaThjd0U5YWtaVS1tSlMzZyIsInN0YXRlIjoiZGQ4MDI4OTQ4NGY1ZTQ2YjQ3MTI4YmNlNjE0ODQzYzIifQ==

# %%
drive_find(n_max = 3)
# Out:
# ERROR while rich displaying an object: Error in names(res) <- prefix: 'names' attribute [1] must be the same length as the vector [0]
#
# Traceback:
# 1. sapply(x, f, simplify = simplify)
# 2. lapply(X = X, FUN = FUN, ...)
# 3. FUN(X[[i]], ...)
# 4. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 5. tryCatchList(expr, classes, parentenv, handlers)
# 6. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 7. doTryCatch(return(expr), name, parentenv, handler)
# 8. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 9. repr::mime2repr[[mime]](obj)
# 10. repr_text.data.frame(obj)
# 11. ellip_limit_arr(obj, rows, cols)
# 12. arr_parts_format(parts)
# 13. structure(lapply(parts, arr_part_format), omit = attr(parts,
#   .     "omit"))
# 14. lapply(parts, arr_part_format)
# 15. FUN(X[[i]], ...)
# 16. arr_part_unpack_tbl(part)
# 17. mapply(tbl_col_format, tbl, names(tbl), SIMPLIFY = FALSE, USE.NAMES = FALSE)
# 18. (function (col, prefix = "")
#   . {
#   .     if (is.data.frame(col)) {
#   .         res <- mapply(tbl_col_format, col, names(col), SIMPLIFY = FALSE,
#   .             USE.NAMES = FALSE)
#   .         res <- do.call(cbind.data.frame, res)
#   .         names(res) <- paste0(prefix, "$", names(res))
#   .         return(res)
#   .     }
#   .     else {
#   .         res <- data.frame(col)
#   .         names(res) <- prefix
#   .         return(res)
#   .     }
#   . })(dots[[1L]][[3L]], dots[[2L]][[3L]])

# %%
drive_find(
  pattern = "deliveries",
  n_max = 10
)
# Out:
# ERROR while rich displaying an object: Error in names(res) <- prefix: 'names' attribute [1] must be the same length as the vector [0]
#
# Traceback:
# 1. sapply(x, f, simplify = simplify)
# 2. lapply(X = X, FUN = FUN, ...)
# 3. FUN(X[[i]], ...)
# 4. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 5. tryCatchList(expr, classes, parentenv, handlers)
# 6. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 7. doTryCatch(return(expr), name, parentenv, handler)
# 8. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 9. repr::mime2repr[[mime]](obj)
# 10. repr_text.data.frame(obj)
# 11. ellip_limit_arr(obj, rows, cols)
# 12. arr_parts_format(parts)
# 13. structure(lapply(parts, arr_part_format), omit = attr(parts,
#   .     "omit"))
# 14. lapply(parts, arr_part_format)
# 15. FUN(X[[i]], ...)
# 16. arr_part_unpack_tbl(part)
# 17. mapply(tbl_col_format, tbl, names(tbl), SIMPLIFY = FALSE, USE.NAMES = FALSE)
# 18. (function (col, prefix = "")
#   . {
#   .     if (is.data.frame(col)) {
#   .         res <- mapply(tbl_col_format, col, names(col), SIMPLIFY = FALSE,
#   .             USE.NAMES = FALSE)
#   .         res <- do.call(cbind.data.frame, res)
#   .         names(res) <- paste0(prefix, "$", names(res))
#   .         return(res)
#   .     }
#   .     else {
#   .         res <- data.frame(col)
#   .         names(res) <- prefix
#   .         return(res)
#   .     }
#   . })(dots[[1L]][[3L]], dots[[2L]][[3L]])

# %%
list.files()
# Out:
# [1] "sample_data"

# %%
library(googledrive)

# %%
drive_find(n_max = 10)
# Out:
# ERROR while rich displaying an object: Error in names(res) <- prefix: 'names' attribute [1] must be the same length as the vector [0]
#
# Traceback:
# 1. sapply(x, f, simplify = simplify)
# 2. lapply(X = X, FUN = FUN, ...)
# 3. FUN(X[[i]], ...)
# 4. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 5. tryCatchList(expr, classes, parentenv, handlers)
# 6. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 7. doTryCatch(return(expr), name, parentenv, handler)
# 8. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 9. repr::mime2repr[[mime]](obj)
# 10. repr_text.data.frame(obj)
# 11. ellip_limit_arr(obj, rows, cols)
# 12. arr_parts_format(parts)
# 13. structure(lapply(parts, arr_part_format), omit = attr(parts,
#   .     "omit"))
# 14. lapply(parts, arr_part_format)
# 15. FUN(X[[i]], ...)
# 16. arr_part_unpack_tbl(part)
# 17. mapply(tbl_col_format, tbl, names(tbl), SIMPLIFY = FALSE, USE.NAMES = FALSE)
# 18. (function (col, prefix = "")
#   . {
#   .     if (is.data.frame(col)) {
#   .         res <- mapply(tbl_col_format, col, names(col), SIMPLIFY = FALSE,
#   .             USE.NAMES = FALSE)
#   .         res <- do.call(cbind.data.frame, res)
#   .         names(res) <- paste0(prefix, "$", names(res))
#   .         return(res)
#   .     }
#   .     else {
#   .         res <- data.frame(col)
#   .         names(res) <- prefix
#   .         return(res)
#   .     }
#   . })(dots[[1L]][[3L]], dots[[2L]][[3L]])

# %%
library(googledrive)

drive_find(pattern = "deliveries", n_max = 20)
# Out:
# ERROR while rich displaying an object: Error in names(res) <- prefix: 'names' attribute [1] must be the same length as the vector [0]
#
# Traceback:
# 1. sapply(x, f, simplify = simplify)
# 2. lapply(X = X, FUN = FUN, ...)
# 3. FUN(X[[i]], ...)
# 4. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 5. tryCatchList(expr, classes, parentenv, handlers)
# 6. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 7. doTryCatch(return(expr), name, parentenv, handler)
# 8. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 9. repr::mime2repr[[mime]](obj)
# 10. repr_text.data.frame(obj)
# 11. ellip_limit_arr(obj, rows, cols)
# 12. arr_parts_format(parts)
# 13. structure(lapply(parts, arr_part_format), omit = attr(parts,
#   .     "omit"))
# 14. lapply(parts, arr_part_format)
# 15. FUN(X[[i]], ...)
# 16. arr_part_unpack_tbl(part)
# 17. mapply(tbl_col_format, tbl, names(tbl), SIMPLIFY = FALSE, USE.NAMES = FALSE)
# 18. (function (col, prefix = "")
#   . {
#   .     if (is.data.frame(col)) {
#   .         res <- mapply(tbl_col_format, col, names(col), SIMPLIFY = FALSE,
#   .             USE.NAMES = FALSE)
#   .         res <- do.call(cbind.data.frame, res)
#   .         names(res) <- paste0(prefix, "$", names(res))
#   .         return(res)
#   .     }
#   .     else {
#   .         res <- data.frame(col)
#   .         names(res) <- prefix
#   .         return(res)
#   .     }
#   . })(dots[[1L]][[3L]], dots[[2L]][[3L]])

# %%
 list.files()
# Out:
# [1] "sample_data"

# %%
list.files(recursive = TRUE)
# Out:
# [1] "sample_data/anscombe.json"
# [2] "sample_data/california_housing_test.csv"
# [3] "sample_data/california_housing_train.csv"
# [4] "sample_data/mnist_test.csv"
# [5] "sample_data/mnist_train_small.csv"
# [6] "sample_data/README.md"

# %%
getwd()
# Out:
# [1] "/content"

# %%
system("find / -name 'deliveries.csv' 2>/dev/null", intern = TRUE)
# Out:
# Warning message in system("find / -name 'deliveries.csv' 2>/dev/null", intern = TRUE):
# “running command 'find / -name 'deliveries.csv' 2>/dev/null' had status 1”
# [1] "/deliveries.csv"
# attr(,"status")
# [1] 1
# attr(,"errmsg")
# [1] "Resource temporarily unavailable"

# %%
deliveries <- read.csv("/deliveries.csv")

head(deliveries)
# Out:
#   delivery_id order_id driver_id vehicle_id hub_id dispatch_time
# 1 DL00001     O00938   D004      V056       H05    2024-06-18 10:57:00
# 2 DL00002     O00004   D138      V007       H02    2025-01-11 18:45:00
# 3 DL00003     O00639   D006      V049       H02    2025-06-02 20:39:00
# 4 DL00004     O00313   D116      V055       H02    2024-03-08 23:31:00
# 5 DL00005     O00844   D108      V034       H01    2025-09-21 11:43:00
# 6 DL00006     O00029   D037      V098       H03    2024-09-11 12:40:00
#   delivery_completed_at      delivery_status route_distance_km
# 1 2024-06-19 09:05:59.904311 Failed          17.26
# 2 2025-01-11 17:39:00.000000 OnTime          10.34
# 3 2025-06-02 21:45:32.366770 OnTime           7.92
# 4 2024-03-09 23:30:08.103702 Delayed         16.42
# 5 2025-09-21 15:45:34.131056 OnTime          14.52
# 6 2024-09-12 17:11:52.384869 Delayed         13.84
#   manual_route_override_count proof_of_completion_missing
# 1 1                           0
# 2 1                           0
# 3 0                           0
# 4 0                           0
# 5 1                           0
# 6 0                           0
#   customer_rating_post_delivery fuel_or_charge_cost
# 1 3.07                          12.05
# 2 5.00                          13.41
# 3 4.98                           8.51
# 4 4.18                          13.62
# 5 4.18                           9.22
# 6 1.57                           9.58

# %%
library(sqldf)

sqldf("
SELECT hub_id,
COUNT(*) AS total_deliveries
FROM deliveries
GROUP BY hub_id
HAVING COUNT(*) > 100
ORDER BY total_deliveries DESC
")
# Out:
#   hub_id total_deliveries
# 1 H01    136
# 2 H08    128
# 3 H04    127
# 4 H03    119
# 5 H07    115
# 6 H05    115
# 7 H02    106
# 8 H06    104
